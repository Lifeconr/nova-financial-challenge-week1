# %%
# Cell 1: Imports and Setup
import sys
import os
sys.path.append(os.path.abspath('../src'))
from financial_eda import FinancialEDA

# %%
# Cell 2: Initialize EDA Class
news_path = r"C:\Users\Senayit\Documents\1\week1\nova-financial-challenge-week1\Data\corrected_analyst_ratings.csv"
stock_dir = r"C:\Users\Senayit\Documents\1\week1\nova-financial-challenge-week1\Data\yfinance_data"
eda = FinancialEDA(news_path, stock_dir)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Senayit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Senayit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Senayit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Senayit\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Cell 3: Descriptive Statistics
desc_stats = eda.descriptive_statistics()
print("Headline Length Stats:", desc_stats['length_stats'])
print("Top Publishers:", desc_stats['publisher_counts'].head(10))
# Out:
# Headline Length Stats: count    172.000000
# mean      40.331395
# std        9.841466
# min       29.000000
# 25%       39.000000
# 50%       39.000000
# 75%       42.000000
# max      120.000000
# Name: headline_length, dtype: float64
# Top Publishers: publisher
# Benzinga Insights          118
# Lisa Levin                  49
# vishwanath@benzinga.com      3
# Vick Meyer                   1
# Benzinga Newsdesk            1
# Name: count, dtype: int64

# %%
# Cell 3: Descriptive Statistics
desc_stats = eda.descriptive_statistics()
print("Headline Length Stats:", desc_stats['length_stats'])
print("Top Publishers:", desc_stats['publisher_counts'].head(10))
# Out:
# Headline Length Stats: count    172.000000
# mean      40.331395
# std        9.841466
# min       29.000000
# 25%       39.000000
# 50%       39.000000
# 75%       42.000000
# max      120.000000
# Name: headline_length, dtype: float64
# Top Publishers: publisher
# Benzinga Insights          118
# Lisa Levin                  49
# vishwanath@benzinga.com      3
# Vick Meyer                   1
# Benzinga Newsdesk            1
# Name: count, dtype: int64

# %%
# Cell 5: Time Series Analysis
time_results = eda.time_series_analysis()
print("Top 5 Daily Counts:", time_results['daily_counts'].nlargest(5))
# Out:
# Top 5 Daily Counts: date_only
# 2020-06-05    62
# 2020-06-03    56
# 2020-05-26    28
# 2020-05-22    26
# dtype: int64

# %%
# Cell 6: Publisher Analysis
pub_results = eda.publisher_analysis()
print("Publisher vs. News Type (Top 5):", pub_results['publisher_news_type'].head())
print("Top Domains:", pub_results['domain_counts'].head(10))
# Out:
# Publisher vs. News Type (Top 5): news_type                Other  Price Target
# publisher
# Benzinga Insights        118.0           0.0
# Benzinga Newsdesk          1.0           0.0
# Lisa Levin                47.0           2.0
# Vick Meyer                 0.0           1.0
# vishwanath@benzinga.com    0.0           3.0
# Top Domains: publisher_domain
# benzinga.com    3
# Name: count, dtype: int64
